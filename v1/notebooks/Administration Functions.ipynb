# %%
import os
import azureml.core
print("SDK version:", azureml.core.VERSION)

from azureml.core import Datastore, Experiment, Workspace
# Out:
# C:\Users\stvanbod\.conda\envs\FishyBusiness\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# SDK version: 1.0.39

# %%
ws = Workspace.from_config()
print('Name: {0}'.format(ws.name), 'Resource Group: {0}'.format(ws.resource_group), 'Location: {0}'.format(ws.location), 'Subscription Id: {0}'.format(ws.subscription_id), sep = '\n')
# Out:
# ...
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# Name: FishyBusiness
# Resource Group: FishyBusiness
# Location: australiaeast
# Subscription Id: 3191ba83-be2b-4b29-8409-f06e2fbb65bd

# %%
Experiment.list(ws)
# Out:
# [Experiment(Name: extract_frames,
#  Workspace: FishyBusiness), Experiment(Name: Hello_World1,
#  Workspace: FishyBusiness), Experiment(Name: FishyBusiness,
#  Workspace: FishyBusiness), Experiment(Name: Hello_World2,
#  Workspace: FishyBusiness)]

# %%
experiment = Experiment(ws, 'extract_frames')
runs = experiment.get_runs()
for run in runs:
    print(run)
# Out:
# Run(Experiment: extract_frames,
# Id: 54203c2d-e193-4f6f-a16b-a32e20165fb6,
# Type: azureml.PipelineRun,
# Status: Running)
# Run(Experiment: extract_frames,
# Id: 47873d7d-c292-4c5d-8f3f-7d7989ac5a9f,
# Type: azureml.PipelineRun,
# Status: Completed)
# Run(Experiment: extract_frames,
# Id: 13766fc5-b608-4d8a-9576-2a2a2eeba180,
# Type: azureml.PipelineRun,
# Status: Failed)
# Run(Experiment: extract_frames,
# Id: ca63f58d-57e0-4df6-b2fb-227bdd6568e5,
# Type: azureml.PipelineRun,
# Status: Completed)
# Run(Experiment: extract_frames,
# Id: 24627c29-68e8-4609-a2b5-201289114c1c,
# Type: azureml.PipelineRun,
# Status: Completed)
# Run(Experiment: extract_frames,
# Id: 1b4193c6-803b-4c0f-9d7d-75d1dd2cefd6,
# Type: azureml.PipelineRun,
# Status: Completed)
# Run(Experiment: extract_frames,
# Id: 20a46777-7d79-42e1-a172-cdfa5cdccc01,
# Type: azureml.PipelineRun,
# Status: Completed)
# Run(Experiment: extract_frames,
# Id: 0f1db42d-a9ae-4441-936c-b20261e5c3f4,
# Type: azureml.PipelineRun,
# ...

# %%
experiment = Experiment(ws, 'extract_frames')
runs = experiment.get_runs()
for run in runs:
    if run.id == 'd43f791c-0e08-4734-bd40-d6b46001adda':
        print(run)
        run.cancel()
